# %%
import numpy as np
from importlib import reload
import agents_complete as agents
reload(agents)
from agents import AdversaryAgent, QLearner

# %%
q_learner = QLearner(alpha = 0.05, gamma = 0.95, epsilon = 0.1)
adv_agent = AdversaryAgent(learner=q_learner, n_episodes=20000)
adv_rew, losses, adv_act, experience = adv_agent.train(is_training=True)
# Out:
# Adversary Training: 100%|██████████| 20000/20000 [16:01<00:00, 20.79it/s]
# Episode 20000, Loss: 0.0394, Reward: 95
#
# --- Saving Adversary weights to ./advRL3_behav/adv_Behav_RNN20000.pth... ---
# --- Save complete ---
